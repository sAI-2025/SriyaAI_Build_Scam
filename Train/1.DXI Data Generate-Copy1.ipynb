# %%
# import pandas as pd
# df = pd.read_csv(r"/content/drive/MyDrive/Train/data/vae_test2_preprocessed_fraud_dxi.csv")

# %%
# df.shape

# %%
# df.isnull().sum()

# %%
# len(df.columns)

# %%
# print(df['is_fraud'].value_counts(normalize=True))

# %%
# # Assuming your dataset is in a DataFrame called df
# fraud_df = df[df['is_fraud'] == 1]
# non_fraud_df = df[df['is_fraud'] == 0]

# # Calculate how many fraud and non-fraud samples to keep
# n_fraud = int(50000 * (len(fraud_df) / len(df)))   # ≈ 86
# n_non_fraud = 50000 - n_fraud                      # ≈ 49914

# # Sample from each class
# fraud_sample = fraud_df.sample(n=n_fraud, random_state=42)
# non_fraud_sample = non_fraud_df.sample(n=n_non_fraud, random_state=42)

# # Combine and shuffle
# df_sampled = pd.concat([fraud_sample, non_fraud_sample]).sample(frac=1, random_state=42).reset_index(drop=True)

# print(df_sampled['is_fraud'].value_counts(normalize=True))
# print(df_sampled.shape)

# %%
# df  = df_sampled.copy()

# %%
# print_categorical_value_counts(df,1631)

# %% [markdown]
# ### Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_data = "/content/drive/MyDrive/Sriya/Datasets/sol_classifcation.csv"
tv =target="price_up_1h"
preprocessing_path = "/content/drive/MyDrive/Sriya/Train/data/solona/sol_classifcation_preprocessed.csv"
dxi_path = "/content/drive/MyDrive/Sriya/Train/data/solona/sol_classifcation__dxi.csv"
regres= False
drop_ = ["timestamp"]

# %% [markdown]
# ### Run

# %%
import pandas as pd
import numpy as np
import random
from sklearn import preprocessing

# %%
df=pd.read_csv(input_data,low_memory=False)

# %%
df.columns
# Out:
# Index(['open', 'volume', 'quote_volume', 'trade_count', 'taker_buy_base',
#        'taker_buy_quote', 'returns', 'sma_25', 'sma_99', 'bb_upper',
#        'bb_lower', 'bb_width', 'bb_position', 'rsi', 'macd', 'macd_signal',
#        'macd_histogram', 'volatility', 'atr', 'volume_sma', 'volume_ratio',
#        'obv', 'stoch_k', 'stoch_d', 'williams_r', 'cci', 'hour', 'day_of_week',
#        'day_of_month', 'month', 'quarter', 'is_weekend', 'volume_momentum_1h',
#        'volume_momentum_24h', 'high_low_ratio', 'close_position',
#        'upper_shadow', 'lower_shadow', 'trend_strength', 'price_up_1h'],
#       dtype='object')

# %%
df.drop(columns=drop_ +["Unnamed: 0"], inplace=True, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18001 entries, 0 to 18000
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   open                 18001 non-null  float64
#  1   volume               18001 non-null  float64
#  2   quote_volume         18001 non-null  float64
#  3   trade_count          18001 non-null  int64
#  4   taker_buy_base       18001 non-null  float64
#  5   taker_buy_quote      18001 non-null  float64
#  6   returns              18001 non-null  float64
#  7   sma_25               18001 non-null  float64
#  8   sma_99               18001 non-null  float64
#  9   bb_upper             18001 non-null  float64
#  10  bb_lower             18001 non-null  float64
#  11  bb_width             18001 non-null  float64
#  12  bb_position          18001 non-null  float64
#  13  rsi                  18001 non-null  float64
#  14  macd                 18001 non-null  float64
# ...

# %%
df
# Out:
#           open      volume  quote_volume  trade_count  taker_buy_base  \
# 0       21.260  7309751.00  1.561562e+08       249826      3552040.00
# 1       21.996  3139691.00  6.877062e+07       119739      1522626.00
# 2       21.664  2363774.00  5.162802e+07        76215      1208262.00
# 3       21.963  1127564.00  2.456428e+07        40368       526544.00
# 4       21.776  1653586.00  3.575813e+07        50178       749504.00
# ...        ...         ...           ...          ...             ...
# 17996  202.330   984059.87  1.998523e+08       127130       519788.92
# 17997  204.240  1015237.82  2.079742e+08       119806       537753.12
# 17998  205.360   622397.72  1.275953e+08        85968       322534.62
# 17999  205.480  1030241.45  2.100839e+08       140664       448953.41
# 18000  203.020   142539.21  2.893496e+07        21116        80226.16
#
#        taker_buy_quote   returns    sma_25      sma_99    bb_upper  ...  \
# ...

# %%
# Create a new column based on whether the target variable is above or below the mean
# above mean set as 1, below mean set as 0
if regres:
    # Save original target variable in new column
    df[f'{tv}_state'] = df[tv]

    # Convert target to binary based on mean
    mean_val = df[tv].mean()
    df[tv] = np.where(df[tv] >= mean_val, 1, 0)

# %%
df[tv].value_counts()
# Out:
# price_up_1h
# 1    9097
# 0    8904
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (18001, 40)

# %%
df.isnull().sum()
# Out:
# open                   0
# volume                 0
# quote_volume           0
# trade_count            0
# taker_buy_base         0
# taker_buy_quote        0
# returns                0
# sma_25                 0
# sma_99                 0
# bb_upper               0
# bb_lower               0
# bb_width               0
# bb_position            0
# rsi                    0
# macd                   0
# macd_signal            0
# macd_histogram         0
# volatility             0
# atr                    0
# volume_sma             0
# volume_ratio           0
# obv                    0
# stoch_k                0
# stoch_d                0
# williams_r             0
# cci                    0
# hour                   0
# day_of_week            0
# day_of_month           0
# month                  0
# quarter                0
# is_weekend             0
# volume_momentum_1h     0
# volume_momentum_24h    0
# high_low_ratio         0
# close_position         0
# upper_shadow           0
# ...

# %%
# df['transaction_location_Siwan, Sikkim'].value_counts()

# %%
# df[' ERC20 total Ether sent contract'].value_counts()

# %%
# train=pd.read_csv(r"/content/drive/MyDrive/Train/data/fulldataplustrainmaster_vae_train_fraud.csv",low_memory=False)
# test=pd.read_csv(r"/content/drive/MyDrive/Train/data/fulldataplustrainmaster_vae_test_fraud.csv",low_memory=False)

# %%
# set(list(train.columns))== set(list(test.columns))

# %%
# def value_counts_dataframe(df):
#     """
#     Returns a DataFrame of value counts for each column.
#     """
#     records = []
#     for col in df.columns:
#         vc = df[col].value_counts()
#         for val, count in vc.items():
#             records.append({'Column': col, 'Value': val, 'Count': count})
#     return pd.DataFrame(records)

# %%
# z =value_counts_dataframe(train)

# %%
# columns_to_drop = {
#     ' ERC20 total Ether sent contract',
#     'avg value sent to contract',
#     # 'max val sent to contract',
#     'min value sent to contract',
#     'total ether sent contracts',
#     'transaction_location_Siwan, Sikkim'
# }

# %%
df.columns
# Out:
# Index(['open', 'volume', 'quote_volume', 'trade_count', 'taker_buy_base',
#        'taker_buy_quote', 'returns', 'sma_25', 'sma_99', 'bb_upper',
#        'bb_lower', 'bb_width', 'bb_position', 'rsi', 'macd', 'macd_signal',
#        'macd_histogram', 'volatility', 'atr', 'volume_sma', 'volume_ratio',
#        'obv', 'stoch_k', 'stoch_d', 'williams_r', 'cci', 'hour', 'day_of_week',
#        'day_of_month', 'month', 'quarter', 'is_weekend', 'volume_momentum_1h',
#        'volume_momentum_24h', 'high_low_ratio', 'close_position',
#        'upper_shadow', 'lower_shadow', 'trend_strength', 'price_up_1h'],
#       dtype='object')

# %%
# df.drop(columns=columns_to_drop,inplace = True)

# %%
df.columns.tolist()
# Out:
# ['open',
#  'volume',
#  'quote_volume',
#  'trade_count',
#  'taker_buy_base',
#  'taker_buy_quote',
#  'returns',
#  'sma_25',
#  'sma_99',
#  'bb_upper',
#  'bb_lower',
#  'bb_width',
#  'bb_position',
#  'rsi',
#  'macd',
#  'macd_signal',
#  'macd_histogram',
#  'volatility',
#  'atr',
#  'volume_sma',
#  'volume_ratio',
#  'obv',
#  'stoch_k',
#  'stoch_d',
#  'williams_r',
#  'cci',
#  'hour',
#  'day_of_week',
#  'day_of_month',
#  'month',
#  'quarter',
#  'is_weekend',
#  'volume_momentum_1h',
#  'volume_momentum_24h',
#  'high_low_ratio',
#  'close_position',
#  'upper_shadow',
#  'lower_shadow',
#  'trend_strength',
#  'price_up_1h']

# %%
df.head(3)
# Out:
#      open     volume  quote_volume  trade_count  taker_buy_base  \
# 0  21.260  7309751.0  1.561562e+08       249826       3552040.0
# 1  21.996  3139691.0  6.877062e+07       119739       1522626.0
# 2  21.664  2363774.0  5.162802e+07        76215       1208262.0
#
#    taker_buy_quote   returns  sma_25  sma_99  bb_upper  ...  quarter  \
# 0     7.591459e+07  0.000000     0.0     0.0       0.0  ...        3
# 1     3.335398e+07 -0.015275     0.0     0.0       0.0  ...        3
# 2     2.639421e+07  0.014081     0.0     0.0       0.0  ...        3
#
#    is_weekend  volume_momentum_1h  volume_momentum_24h  high_low_ratio  \
# 0           0            0.000000                  0.0        1.058166
# 1           0           -0.570479                  0.0        1.026352
# 2           0           -0.247132                  0.0        1.022942
#
#    close_position  upper_shadow  lower_shadow  trend_strength  price_up_1h
# ...

# %%
#df.reset_index(inplace=True)
# df.drop(columns=['Unnamed: 0'], inplace=True, errors='ignore')

# # df

# %%
# df1=pd.read_excel(r"C:\Users\Prabhat\Desktop\Data.xlsx")
# #df.reset_index(inplace=True)
# # df = df.drop("Claim_Amount", axis=1)
# df1

# %%
print(df[tv].value_counts(normalize=True))
# Out:
# price_up_1h
# 1    0.505361
# 0    0.494639
# Name: proportion, dtype: float64

# %%
# df.shape
df.isnull().sum()
# Out:
# open                   0
# volume                 0
# quote_volume           0
# trade_count            0
# taker_buy_base         0
# taker_buy_quote        0
# returns                0
# sma_25                 0
# sma_99                 0
# bb_upper               0
# bb_lower               0
# bb_width               0
# bb_position            0
# rsi                    0
# macd                   0
# macd_signal            0
# macd_histogram         0
# volatility             0
# atr                    0
# volume_sma             0
# volume_ratio           0
# obv                    0
# stoch_k                0
# stoch_d                0
# williams_r             0
# cci                    0
# hour                   0
# day_of_week            0
# day_of_month           0
# month                  0
# quarter                0
# is_weekend             0
# volume_momentum_1h     0
# volume_momentum_24h    0
# high_low_ratio         0
# close_position         0
# upper_shadow           0
# ...

# %%
df.columns
# Out:
# Index(['open', 'volume', 'quote_volume', 'trade_count', 'taker_buy_base',
#        'taker_buy_quote', 'returns', 'sma_25', 'sma_99', 'bb_upper',
#        'bb_lower', 'bb_width', 'bb_position', 'rsi', 'macd', 'macd_signal',
#        'macd_histogram', 'volatility', 'atr', 'volume_sma', 'volume_ratio',
#        'obv', 'stoch_k', 'stoch_d', 'williams_r', 'cci', 'hour', 'day_of_week',
#        'day_of_month', 'month', 'quarter', 'is_weekend', 'volume_momentum_1h',
#        'volume_momentum_24h', 'high_low_ratio', 'close_position',
#        'upper_shadow', 'lower_shadow', 'trend_strength', 'price_up_1h'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18001 entries, 0 to 18000
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   open                 18001 non-null  float64
#  1   volume               18001 non-null  float64
#  2   quote_volume         18001 non-null  float64
#  3   trade_count          18001 non-null  int64
#  4   taker_buy_base       18001 non-null  float64
#  5   taker_buy_quote      18001 non-null  float64
#  6   returns              18001 non-null  float64
#  7   sma_25               18001 non-null  float64
#  8   sma_99               18001 non-null  float64
#  9   bb_upper             18001 non-null  float64
#  10  bb_lower             18001 non-null  float64
#  11  bb_width             18001 non-null  float64
#  12  bb_position          18001 non-null  float64
#  13  rsi                  18001 non-null  float64
#  14  macd                 18001 non-null  float64
# ...

# %%
def generate_random_ids(num_rows, prefix="prim_", id_range=(100000, 9999999999)):
    random_ids = random.sample(range(*id_range), num_rows)  # Unique numbers
    return [f"{prefix}_{id}" for id in random_ids]
df.insert(0, "primary_key", generate_random_ids(len(df)))
df.head()
# Out:
#         primary_key    open     volume  quote_volume  trade_count  \
# 0  prim__8814246022  21.260  7309751.0  1.561562e+08       249826
# 1  prim__4655332133  21.996  3139691.0  6.877062e+07       119739
# 2   prim__677322728  21.664  2363774.0  5.162802e+07        76215
# 3  prim__7844886590  21.963  1127564.0  2.456428e+07        40368
# 4  prim__5997576097  21.776  1653586.0  3.575813e+07        50178
#
#    taker_buy_base  taker_buy_quote   returns  sma_25  sma_99  ...  quarter  \
# 0       3552040.0     7.591459e+07  0.000000     0.0     0.0  ...        3
# 1       1522626.0     3.335398e+07 -0.015275     0.0     0.0  ...        3
# 2       1208262.0     2.639421e+07  0.014081     0.0     0.0  ...        3
# 3        526544.0     1.147062e+07 -0.008695     0.0     0.0  ...        3
# 4        749504.0     1.621109e+07 -0.016395     0.0     0.0  ...        3
#
#    is_weekend  volume_momentum_1h  volume_momentum_24h  high_low_ratio  \
# ...

# %% [markdown]
# # Preprocessed Path

# %%
df.to_csv(preprocessing_path, index=False)

# %%
df.describe()
# Out:
#                open        volume  quote_volume   trade_count  taker_buy_base  \
# count  18001.000000  1.800100e+04  1.800100e+04  1.800100e+04    1.800100e+04
# mean     139.217578  1.031642e+06  1.311743e+08  9.642927e+04    5.083678e+05
# std       57.093246  1.001071e+06  1.325283e+08  8.202954e+04    4.961073e+05
# min       17.499000  6.844500e+04  3.643328e+06  6.463000e+03    3.214000e+04
# 25%      110.384000  4.672080e+05  5.760055e+07  4.761500e+04    2.288780e+05
# 50%      146.620000  7.403400e+05  9.467038e+07  7.408600e+04    3.644060e+05
# 75%      175.797000  1.224431e+06  1.590443e+08  1.174310e+05    6.048730e+05
# max      286.090000  1.712757e+07  2.932765e+09  1.364193e+06    8.610843e+06
#
#        taker_buy_quote       returns        sma_25        sma_99  \
# count     1.800100e+04  18001.000000  18001.000000  18001.000000
# mean      6.447259e+07      0.000173    139.076591    138.607710
# std       6.496196e+07      0.009953     57.136793     57.302372
# ...

# %%
# df.reset_index(inplace=True)
# df.rename(columns={'index': 'primary'}, inplace=True)

# %%
df.columns
# Out:
# Index(['primary_key', 'open', 'volume', 'quote_volume', 'trade_count',
#        'taker_buy_base', 'taker_buy_quote', 'returns', 'sma_25', 'sma_99',
#        'bb_upper', 'bb_lower', 'bb_width', 'bb_position', 'rsi', 'macd',
#        'macd_signal', 'macd_histogram', 'volatility', 'atr', 'volume_sma',
#        'volume_ratio', 'obv', 'stoch_k', 'stoch_d', 'williams_r', 'cci',
#        'hour', 'day_of_week', 'day_of_month', 'month', 'quarter', 'is_weekend',
#        'volume_momentum_1h', 'volume_momentum_24h', 'high_low_ratio',
#        'close_position', 'upper_shadow', 'lower_shadow', 'trend_strength',
#        'price_up_1h'],
#       dtype='object')

# %%
# df['Compared to National'].value_counts()

# %%
# df[f'{tv}_state'] = np.where(df[tv] >= df[tv].mean(), '1', '0')
# df

# %%
df[tv].value_counts()
# Out:
# price_up_1h
# 1    9097
# 0    8904
# Name: count, dtype: int64

# %%
# df=df.drop(columns=['Version.[Version Name]'])

# %%
# df[f'{tv}_state'].value_counts()

# %%
from sklearn import preprocessing

# %%
if (df[tv].dtypes == 'object'):
    le = preprocessing.LabelEncoder()
    df[tv] = le.fit_transform(df[tv])
else:
    pass

for i in df.columns:
    if (df[i].dtypes == 'object' or df[i].dtypes == 'bool') and (len(df[i].unique())>=2):
        le = preprocessing.LabelEncoder()
        df[i] = le.fit_transform(df[i])

    if (df[i].dtypes == 'object') and (len(df[i].unique())>= 10):

        le = preprocessing.LabelEncoder()
        df[i] = le.fit_transform(df[i])
    else:
        pass

df_upd = df

# %%
df_main=df_upd

# %%
df_main
# Out:
#        primary_key     open      volume  quote_volume  trade_count  \
# 0            15673   21.260  7309751.00  1.561562e+08       249826
# 1             7308   21.996  3139691.00  6.877062e+07       119739
# 2            11547   21.664  2363774.00  5.162802e+07        76215
# 3            13737   21.963  1127564.00  2.456428e+07        40368
# 4            10025   21.776  1653586.00  3.575813e+07        50178
# ...            ...      ...         ...           ...          ...
# 17996         3108  202.330   984059.87  1.998523e+08       127130
# 17997         6807  204.240  1015237.82  2.079742e+08       119806
# 17998        14912  205.360   622397.72  1.275953e+08        85968
# 17999         1085  205.480  1030241.45  2.100839e+08       140664
# 18000        11707  203.020   142539.21  2.893496e+07        21116
#
#        taker_buy_base  taker_buy_quote   returns    sma_25      sma_99  ...  \
# 0          3552040.00     7.591459e+07  0.000000    0.0000    0.000000  ...
# ...

# %% [markdown]
# # DataFrame for DXI

# %%
primarykey = 'primary_key'
x = df_main.drop([tv,primarykey],axis=1)
y = df_main[f'{tv}']

# %%
dff=x.columns

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.2,max_iter=10000)
clf.fit(x,y)
lasso_weight= clf.coef_

#update dataframe
min_max = []
max_f=[]
for i in range(len(dff)):
    if lasso_weight[i] < 0 :
        min_max.append(dff[i])
    else:
        max_f.append('MAX')
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.571e+02, tolerance: 4.500e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
df_main.drop([tv],axis=1,inplace=True)

# %%
if tv in df_main.columns:
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
df_main.columns
# Out:
# Index(['primary_key', 'open', 'volume', 'quote_volume', 'trade_count',
#        'taker_buy_base', 'taker_buy_quote', 'returns', 'sma_25', 'sma_99',
#        'bb_upper', 'bb_lower', 'bb_width', 'bb_position', 'rsi', 'macd',
#        'macd_signal', 'macd_histogram', 'volatility', 'atr', 'volume_sma',
#        'volume_ratio', 'obv', 'stoch_k', 'stoch_d', 'williams_r', 'cci',
#        'hour', 'day_of_week', 'day_of_month', 'month', 'quarter', 'is_weekend',
#        'volume_momentum_1h', 'volume_momentum_24h', 'high_low_ratio',
#        'close_position', 'upper_shadow', 'lower_shadow', 'trend_strength'],
#       dtype='object')

# %%
df_main
# Out:
#        primary_key     open      volume  quote_volume  trade_count  \
# 0            15673   21.260  7309751.00  1.561562e+08       249826
# 1             7308   21.996  3139691.00  6.877062e+07       119739
# 2            11547   21.664  2363774.00  5.162802e+07        76215
# 3            13737   21.963  1127564.00  2.456428e+07        40368
# 4            10025   21.776  1653586.00  3.575813e+07        50178
# ...            ...      ...         ...           ...          ...
# 17996         3108  202.330   984059.87  1.998523e+08       127130
# 17997         6807  204.240  1015237.82  2.079742e+08       119806
# 17998        14912  205.360   622397.72  1.275953e+08        85968
# 17999         1085  205.480  1030241.45  2.100839e+08       140664
# 18000        11707  203.020   142539.21  2.893496e+07        21116
#
#        taker_buy_base  taker_buy_quote   returns    sma_25      sma_99  ...  \
# 0          3552040.00     7.591459e+07  0.000000    0.0000    0.000000  ...
# ...

# %%
features=list(df_main.columns)

minimum_value=[]
maximum_value=[]
minmax_value=[]
catogorical_value=[]

# %%
for i in range(len(features)):

        if features[i] in min_max:
            minmax_value.append('MIN')
            catogorical_value.append('Behavior')
        else:
            minmax_value.append('MAX')
            catogorical_value.append('Behavior')
        try:
            minimum=min(list(df_main[features[i]]))
            maximum=max(list(df_main[features[i]]))
        except:
            minimum=''
            maximum=''
        minimum_value.append(minimum)
        maximum_value.append(maximum)

# %%
minimum_value[0]='Min_Value'
maximum_value[0]='Max_Value'
minmax_value[0] = 'minmax'
catogorical_value[0]='Category'

# %%
df_mains=pd.DataFrame()
df_mains['0']=minimum_value
df_mains['1']=maximum_value
df_mains['2']=minmax_value
df_mains['3']=catogorical_value

# %%
df_m=df_mains.T
df_m.columns=df_main.columns


df_m.reset_index(drop=True, inplace=True)
df_main.reset_index(drop=True, inplace=True)
frames=[df_m,df_main]

result = pd.concat(frames, keys=['x', 'y'])

# %%
result
# Out:
#         primary_key      open      volume     quote_volume trade_count  \
# x 0       Min_Value    17.499     68445.0      3643327.945        6463
#   1       Max_Value    286.09  17127571.0   2932764925.504     1364193
#   2          minmax       MAX         MAX              MIN         MIN
#   3        Category  Behavior    Behavior         Behavior    Behavior
# y 0           15673     21.26   7309751.0    156156150.334      249826
# ...             ...       ...         ...              ...         ...
#   17996        3108    202.33   984059.87  199852291.60186      127130
#   17997        6807    204.24  1015237.82  207974232.00572      119806
#   17998       14912    205.36   622397.72   127595303.9643       85968
#   17999        1085    205.48  1030241.45  210083878.62224      140664
#   18000       11707    203.02   142539.21    28934963.2438       21116
#
#         taker_buy_base  taker_buy_quote   returns    sma_25      sma_99  ...  \
# ...

# %%
df
# Out:
#        primary_key     open      volume  quote_volume  trade_count  \
# 0            15673   21.260  7309751.00  1.561562e+08       249826
# 1             7308   21.996  3139691.00  6.877062e+07       119739
# 2            11547   21.664  2363774.00  5.162802e+07        76215
# 3            13737   21.963  1127564.00  2.456428e+07        40368
# 4            10025   21.776  1653586.00  3.575813e+07        50178
# ...            ...      ...         ...           ...          ...
# 17996         3108  202.330   984059.87  1.998523e+08       127130
# 17997         6807  204.240  1015237.82  2.079742e+08       119806
# 17998        14912  205.360   622397.72  1.275953e+08        85968
# 17999         1085  205.480  1030241.45  2.100839e+08       140664
# 18000        11707  203.020   142539.21  2.893496e+07        21116
#
#        taker_buy_base  taker_buy_quote   returns    sma_25      sma_99  ...  \
# 0          3552040.00     7.591459e+07  0.000000    0.0000    0.000000  ...
# ...

# %%
# name=dict(zip(le.classes_,le.transform(le.classes_)))
# print(name)

# %%
result.to_csv(dxi_path, index=False)

# %%
result.head(5)
# Out:
#     primary_key      open      volume    quote_volume trade_count  \
# x 0   Min_Value    17.499     68445.0     3643327.945        6463
#   1   Max_Value    286.09  17127571.0  2932764925.504     1364193
#   2      minmax       MAX         MAX             MIN         MIN
#   3    Category  Behavior    Behavior        Behavior    Behavior
# y 0       15673     21.26   7309751.0   156156150.334      249826
#
#     taker_buy_base taker_buy_quote   returns    sma_25      sma_99  ...  \
# x 0        32140.0     1623660.435  -0.09035       0.0         0.0  ...
#   1      8610843.0  1453152444.603  0.118416   268.386  254.832525  ...
#   2            MIN             MAX       MAX       MAX         MAX  ...
#   3       Behavior        Behavior  Behavior  Behavior    Behavior  ...
# y 0      3552040.0    75914586.286       0.0       0.0         0.0  ...
#
#         month   quarter is_weekend volume_momentum_1h volume_momentum_24h  \
# ...
